# %%
from qiskit import QuantumCircuit,transpile
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
simu=AerSimulator()
circ= QuantumCircuit(2,2)
circ.h(0)
circ.cx(1,0)
circ.measure([0,1],[0,1])
compiled_circ=transpile(circ,simu)
j=simu.run(compiled_circ,short=100)
result=j.result()
counts=result.get_counts(compiled_circ)
print("total count in 00 and 11",counts)
circ.draw("mpl")
# Out:
# total count in 00 and 11 {'01': 498, '00': 526}
